# %%
from pandas_profiling import ProfileReport
import pandas as pd
from vega_datasets import data

#VITOR DA SILVA SANTANA || ESPW || RM99586
#LUCCA ALEXANDRE MACHADO || ESPW || RM99700
#VICTOR AUGUSTO WITTNER || ESPW || 98667

# %%
# %pip install ipywidgets
# %pip install --upgrade setuptools

# %%
df = data.cars()
df.isnull().any()
df.fillna(0, inplace=True)
# Out:
# Name                False
# Miles_per_Gallon    False
# Cylinders           False
# Displacement        False
# Horsepower          False
# Weight_in_lbs       False
# Acceleration        False
# Year                False
# Origin              False
# dtype: bool

# %%
profile = ProfileReport(df, title= "Profile Report -- Cars")
profile
# Out:
# ...
# Render HTML: 100%|██████████| 1/1 [00:00<00:00,  2.33it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.10.0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-10-09 18:17:30.348602&quot;&gt;&lt;title&gt;Profile Report -- Cars&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
profile.to_file("Relatório de carros")
# Out:
# c:\Users\vitor\AppData\Local\Programs\Python\Python312\Lib\site-packages\ydata_profiling\profile_report.py:384: UserWarning: Extension  not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 200.12it/s]
